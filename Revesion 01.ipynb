# %%
import pandas as pd

# %%
df=pd.read_csv("C:/Users/Pramoda A S/Desktop/AIML Documents/DataSets in CSV files/titanic.csv")
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df["Name"]="GPT"

# %%
df["Name"]
# Out:
# 0      GPT
# 1      GPT
# 2      GPT
# 3      GPT
# 4      GPT
#       ...
# 886    GPT
# 887    GPT
# 888    GPT
# 889    GPT
# 890    GPT
# Name: Name, Length: 891, dtype: object

# %%
df["New_Fare"]=df['fare']+10

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone Name  New_Fare
# 0    man        True  NaN  Southampton    no  False  GPT   17.2500
# 1  woman       False    C    Cherbourg   yes  False  GPT   81.2833
# 2  woman       False  NaN  Southampton   yes   True  GPT   17.9250
# 3  woman       False    C  Southampton   yes  False  GPT   63.1000
# 4    man        True  NaN  Southampton    no   True  GPT   18.0500

# %%
df["Age_Cat"]=df["age"].apply(lambda x: "Seniour" if x> 60 else "Juniour")

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone Name  New_Fare  Age_Cat
# 0    man        True  NaN  Southampton    no  False  GPT   17.2500  Juniour
# 1  woman       False    C    Cherbourg   yes  False  GPT   81.2833  Juniour
# 2  woman       False  NaN  Southampton   yes   True  GPT   17.9250  Juniour
# 3  woman       False    C  Southampton   yes  False  GPT   63.1000  Juniour
# 4    man        True  NaN  Southampton    no   True  GPT   18.0500  Juniour

# %%
df["survived"]=df["survived"].apply(lambda x: "Yes" if x==1 else "No")

# %%
df.head(10)
# Out:
#   survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0       No       3    male  22.0      1      0   7.2500        S   Third
# 1      Yes       1  female  38.0      1      0  71.2833        C   First
# 2      Yes       3  female  26.0      0      0   7.9250        S   Third
# 3      Yes       1  female  35.0      1      0  53.1000        S   First
# 4       No       3    male  35.0      0      0   8.0500        S   Third
# 5       No       3    male   NaN      0      0   8.4583        Q   Third
# 6       No       1    male  54.0      0      0  51.8625        S   First
# 7       No       3    male   2.0      3      1  21.0750        S   Third
# 8      Yes       3  female  27.0      0      2  11.1333        S   Third
# 9      Yes       2  female  14.0      1      0  30.0708        C  Second
#
#      who  adult_male deck  embark_town alive  alone Name  New_Fare  Age_Cat
# 0    man        True  NaN  Southampton    no  False  GPT   17.2500  Juniour
# ...

# %% [markdown]
# # Removing

# %%
df.drop("New_Fare",axis=1,inplace=True)

# %%
df
# Out:
#     survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0         No       3    male  22.0      1      0   7.2500        S   Third
# 1        Yes       1  female  38.0      1      0  71.2833        C   First
# 2        Yes       3  female  26.0      0      0   7.9250        S   Third
# 3        Yes       1  female  35.0      1      0  53.1000        S   First
# 4         No       3    male  35.0      0      0   8.0500        S   Third
# ..       ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886       No       2    male  27.0      0      0  13.0000        S  Second
# 887      Yes       1  female  19.0      0      0  30.0000        S   First
# 888       No       3  female   NaN      1      2  23.4500        S   Third
# 889      Yes       1    male  26.0      0      0  30.0000        C   First
# 890       No       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone Name  Age_Cat
# ...

# %%
df.drop(["Age_Cat","Name"],axis=1,inplace=True)

# %%
df
# Out:
#     survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0         No       3    male  22.0      1      0   7.2500        S   Third
# 1        Yes       1  female  38.0      1      0  71.2833        C   First
# 2        Yes       3  female  26.0      0      0   7.9250        S   Third
# 3        Yes       1  female  35.0      1      0  53.1000        S   First
# 4         No       3    male  35.0      0      0   8.0500        S   Third
# ..       ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886       No       2    male  27.0      0      0  13.0000        S  Second
# 887      Yes       1  female  19.0      0      0  30.0000        S   First
# 888       No       3  female   NaN      1      2  23.4500        S   Third
# 889      Yes       1    male  26.0      0      0  30.0000        C   First
# 890       No       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df.drop(['sex','age','sibsp','parch','fare','who','class'],axis=1,inplace=True)

# %%
df
# Out:
#     survived  pclass embarked  adult_male deck  embark_town alive  alone
# 0         No       3        S        True  NaN  Southampton    no  False
# 1        Yes       1        C       False    C    Cherbourg   yes  False
# 2        Yes       3        S       False  NaN  Southampton   yes   True
# 3        Yes       1        S       False    C  Southampton   yes  False
# 4         No       3        S        True  NaN  Southampton    no   True
# ..       ...     ...      ...         ...  ...          ...   ...    ...
# 886       No       2        S        True  NaN  Southampton    no   True
# 887      Yes       1        S       False    B  Southampton   yes   True
# 888       No       3        S       False  NaN  Southampton    no  False
# 889      Yes       1        C        True    C    Cherbourg   yes   True
# 890       No       3        Q        True  NaN   Queenstown    no   True
#
# [891 rows x 8 columns]

# %% [markdown]
# # adding a Row

# %%
new_row={"survived':"No",'pclass':2,'embarked':"Q",'adult_male':"True",'deck':"C",'embark_town':"Cherbourg",'alive':"yes",'alone':"True"}
new_row
# Out:
#   File "<ipython-input-89-15fa1af4d1b3>", line 1
#     new_row={"survived':"No",'pclass':2,'embarked':"Q",'adult_male':"True",'deck':"C",'embark_town':"Cherbourg",'alive':"yes",'alone':"True"}
#                          ^
# SyntaxError: invalid syntax

# %%
df.loc[len(df)]=["Yes",2,"S","First","True","B","Southampton",'yes',"True"]
df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-90-66b6c6c9eec3> in <module>
# ----> 1 df.loc[len(df)]=["Yes",2,"S","First","True","B","Southampton",'yes',"True"]
#       2 df
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in __setitem__(self, key, value)
#     669             key = com.apply_if_callable(key, self.obj)
#     670         indexer = self._get_setitem_indexer(key)
# --> 671         self._setitem_with_indexer(indexer, value)
#     672
#     673     def _validate_key(self, key, axis: int):
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _setitem_with_indexer(self, indexer, value)
#     873
#     874             if missing:
# --> 875                 return self._setitem_with_indexer_missing(indexer, value)
#     876
#     877         # set
#
# ...

# %%
df.loc[2]=[5,4,"C","True","C","Cherbourg",'yes',"False"]

# %%
df.loc(len)==[6,7,'D',"True","C","Cherbourg",'yes','True']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\generic.py in ?(cls, axis)
#     576             return cls._AXIS_TO_AXIS_NUMBER[axis]
#     577         except KeyError:
# --> 578             raise ValueError(f"No axis named {axis} for object type {cls.__name__}")
#
# KeyError: <built-in function len>
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9712\2590848186.py in ?()
# ----> 1 df.loc(len)==[6,7,'D',"True","C","Cherbourg",'yes','True']
#
# ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\indexing.py in ?(self, axis)
#     734         # we need to return a copy of ourselves
#     735         new_self = type(self)(self.name, self.obj)
#     736
# ...

# %%
df
# Out:
#     survived  pclass embarked adult_male deck  embark_town alive  alone
# 0         No       3        S       True  NaN  Southampton    no  False
# 1        Yes       1        C      False    C    Cherbourg   yes  False
# 2          5       4        C       True    C    Cherbourg   yes  False
# 3        Yes       1        S      False    C  Southampton   yes  False
# 4         No       3        S       True  NaN  Southampton    no   True
# ..       ...     ...      ...        ...  ...          ...   ...    ...
# 886       No       2        S       True  NaN  Southampton    no   True
# 887      Yes       1        S      False    B  Southampton   yes   True
# 888       No       3        S      False  NaN  Southampton    no  False
# 889      Yes       1        C       True    C    Cherbourg   yes   True
# 890       No       3        Q       True  NaN   Queenstown    no   True
#
# [891 rows x 8 columns]

# %% [markdown]
# # deleting Null values.

# %%
df.isnull().sum()
# Out:
# survived         0
# pclass           0
# embarked         2
# adult_male       0
# deck           687
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
df.head()
# Out:
#   survived  pclass embarked adult_male deck  embark_town alive  alone
# 0       No       3        S       True  NaN  Southampton    no  False
# 1      Yes       1        C      False    C    Cherbourg   yes  False
# 2        5       4        C       True    C    Cherbourg   yes  False
# 3      Yes       1        S      False    C  Southampton   yes  False
# 4       No       3        S       True  NaN  Southampton    no   True

# %%
df
# Out:
#     survived  pclass embarked adult_male deck  embark_town alive  alone
# 0         No       3        S       True  NaN  Southampton    no  False
# 1        Yes       1        C      False    C    Cherbourg   yes  False
# 2          5       4        C       True    C    Cherbourg   yes  False
# 3        Yes       1        S      False    C  Southampton   yes  False
# 4         No       3        S       True  NaN  Southampton    no   True
# ..       ...     ...      ...        ...  ...          ...   ...    ...
# 886       No       2        S       True  NaN  Southampton    no   True
# 887      Yes       1        S      False    B  Southampton   yes   True
# 888       No       3        S      False  NaN  Southampton    no  False
# 889      Yes       1        C       True    C    Cherbourg   yes   True
# 890       No       3        Q       True  NaN   Queenstown    no   True
#
# [891 rows x 8 columns]

# %%
df=df[df["deck"].notna()]

#

# %%
df
#delete the all null values

# df=df.dropna()
# Out:
#     survived  pclass embarked adult_male deck  embark_town alive  alone
# 1        Yes       1        C      False    C    Cherbourg   yes  False
# 2          5       4        C       True    C    Cherbourg   yes  False
# 3        Yes       1        S      False    C  Southampton   yes  False
# 6         No       1        S       True    E  Southampton    no   True
# 10       Yes       3        S      False    G  Southampton   yes  False
# ..       ...     ...      ...        ...  ...          ...   ...    ...
# 871      Yes       1        S      False    D  Southampton   yes  False
# 872       No       1        S       True    B  Southampton    no   True
# 879      Yes       1        C      False    C    Cherbourg   yes  False
# 887      Yes       1        S      False    B  Southampton   yes   True
# 889      Yes       1        C       True    C    Cherbourg   yes   True
#
# [204 rows x 8 columns]

# %%
c=df[["pclass","embarked"]].value_counts().unstack()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-6-4da05fbfd1e3> in <module>
# ----> 1 c=df[["pclass","embarked"]].value_counts().unstack()
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'value_counts'

# %%
a=df.groupby(["pclass","embarked"]).size().unstack()
a
# Out:
# embarked   C   Q    S
# pclass
# 1         85   2  127
# 2         17   3  164
# 3         66  72  353

# %%
import pandas as pd
