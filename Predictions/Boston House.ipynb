# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
# %matplotlib inline

# %%
df=pd.read_csv("C:/Users/Pramoda A S/Desktop/AIML Documents/DataSets in CSV files/Boston.csv")
df
# Out:
#      Unnamed: 0     crim    zn  indus  chas    nox     rm   age     dis  rad  \
# 0             1  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1
# 1             2  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2
# 2             3  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2
# 3             4  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3
# 4             5  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3
# ..          ...      ...   ...    ...   ...    ...    ...   ...     ...  ...
# 501         502  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1
# 502         503  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1
# 503         504  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1
# 504         505  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1
# 505         506  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1
#
#      tax  ptratio   black  lstat  medv
# 0    296     15.3  396.90   4.98  24.0
# 1    242     17.8  396.90   9.14  21.6
# 2    242     17.8  392.83   4.03  34.7
# 3    222     18.7  394.63   2.94  33.4
# 4    222     18.7  396.90   5.33  36.2
# ..   ...      ...     ...    ...   ...
# 501  273     21.0  391.99   9.67  22.4
# 502  273     21.0  396.90   9.08  20.6
# 503  273     21.0  396.90   5.64  23.9
# 504  273     21.0  393.45   6.48  22.0
# 505  273     21.0  396.90   7.88  11.9
#
# [506 rows x 15 columns]

# %%
df.head()
# Out:
#    Unnamed: 0     crim    zn  indus  chas    nox     rm   age     dis  rad  \
# 0           1  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1
# 1           2  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2
# 2           3  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2
# 3           4  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3
# 4           5  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3
#
#    tax  ptratio   black  lstat  medv
# 0  296     15.3  396.90   4.98  24.0
# 1  242     17.8  396.90   9.14  21.6
# 2  242     17.8  392.83   4.03  34.7
# 3  222     18.7  394.63   2.94  33.4
# 4  222     18.7  396.90   5.33  36.2

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 15 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  506 non-null    int64
#  1   crim        506 non-null    float64
#  2   zn          506 non-null    float64
#  3   indus       506 non-null    float64
#  4   chas        506 non-null    int64
#  5   nox         506 non-null    float64
#  6   rm          506 non-null    float64
#  7   age         506 non-null    float64
#  8   dis         506 non-null    float64
#  9   rad         506 non-null    int64
#  10  tax         506 non-null    int64
#  11  ptratio     506 non-null    float64
#  12  black       506 non-null    float64
#  13  lstat       506 non-null    float64
#  14  medv        506 non-null    float64
# dtypes: float64(11), int64(4)
# memory usage: 59.4 KB

# %%
df.shape
# Out:
# (506, 15)

# %%
df.head()
# Out:
#    Unnamed: 0     crim    zn  indus  chas    nox     rm   age     dis  rad  \
# 0           1  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1
# 1           2  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2
# 2           3  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2
# 3           4  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3
# 4           5  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3
#
#    tax  ptratio   black  lstat  medv
# 0  296     15.3  396.90   4.98  24.0
# 1  242     17.8  396.90   9.14  21.6
# 2  242     17.8  392.83   4.03  34.7
# 3  222     18.7  394.63   2.94  33.4
# 4  222     18.7  396.90   5.33  36.2

# %% [markdown]
# # Data preprocessing

# %%
df.isnull().sum()
# Out:
# Unnamed: 0    0
# crim          0
# zn            0
# indus         0
# chas          0
# nox           0
# rm            0
# age           0
# dis           0
# rad           0
# tax           0
# ptratio       0
# black         0
# lstat         0
# medv          0
# dtype: int64

# %%
df['age'].plot(kind="box")
plt.show()

# %%
df['indus'].plot(kind="box")
plt.show()

# %%
df['lstat'].plot(kind="box")
plt.show()

# %%
q1=df['lstat'].quantile(0.25)
q3=df['lstat'].quantile(0.75)

# %%
iqr=q3-q1

# %%
upper_bound=q3+(1.5*iqr)
lower_bound=q1-(1.5*iqr)

# %%
a_arr=df['lstat']
out=a_arr[(a_arr<=lower_bound) | (a_arr>=upper_bound)]

# %%
print(out)
# Out:
# 141    34.41
# 373    34.77
# 374    37.97
# 387    31.99
# 412    34.37
# 414    36.98
# 438    34.02
# Name: lstat, dtype: float64

# %%
ls_arr=df['lstat']
lower_cap=np.percentile(ls_arr,1)
upper_cap=np.percentile(ls_arr,99)

# %%
for i in df['lstat']:
    if i<lower_bound:
        df['lstat']=df['lstat'].replace(i,lower_cap)
    elif i>upper_bound:
        df['lstat']=df['lstat'].replace(i,upper_cap)

# %%
df['lstat'].plot(kind='box')
# Out:
# <Axes: >

# %%
q1=df['lstat'].quantile(0.25)
q3=df['lstat'].quantile(0.75)

iqr=q3-q1

upper_bound=q3+(1.5*iqr)
lower_bound=q1-(1.5*iqr)

a_arr=df['lstat']
out=a_arr[(a_arr<=lower_bound) | (a_arr>=upper_bound)]

print(out)

ls_arr=df['lstat']
lower_cap=np.percentile(ls_arr,1)
upper_cap=np.percentile(ls_arr,99)

for i in df['lstat']:
    if i<lower_bound:
        df['lstat']=df['lstat'].replace(i,lower_cap)
    elif i>upper_bound:
        df['lstat']=df['lstat'].replace(i,upper_cap)
# Out:
# 141    33.9185
# 373    33.9185
# 374    33.9185
# 387    33.9185
# 412    33.9185
# 414    33.9185
# 438    33.9185
# Name: lstat, dtype: float64

# %%
df['lstat'].plot(kind='box')
# Out:
# <Axes: >

# %%
df.isnull().sum()
# Out:
# Unnamed: 0    0
# crim          0
# zn            0
# indus         0
# chas          0
# nox           0
# rm            0
# age           0
# dis           0
# rad           0
# tax           0
# ptratio       0
# black         0
# lstat         0
# medv          0
# dtype: int64

# %% [markdown]
# # Prepare the data for training

# %%
X = pd.DataFrame(np.c_[df['lstat'], df['rm']], columns = ['lstat','rm'])
Y = df['medv']

# %% [markdown]
# # Split the data into training and testing sets

# %%
from sklearn.model_selection import train_test_split
# splits the training and test data set in 80% : 20%
# assign random_state to any value.This ensures consistency.
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.2, random_state=101)
print(X_train.shape)
print(X_test.shape)
print(Y_train.shape)
print(Y_test.shape)
# Out:
# (404, 2)
# (102, 2)
# (404,)
# (102,)

# %% [markdown]
# # Train the model using sklearn LinearRegression

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
model = LinearRegression()
model.fit(X_train, Y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X_test)
y_pred
# Out:
# array([36.87977549, 31.58573783, 20.34587553, 20.13840532, 29.3887625 ,
#        31.00707078, 40.19480592, 10.87260984, 31.01187062,  8.92154   ,
#        27.58541122, 14.53990061, 18.71868508, 23.46205081, 23.64744735,
#        19.21856679,  8.22881493, 31.40601031, 28.0313401 , 26.60176773,
#        12.33869162, 18.3468428 , 24.15811884, 31.77228826, 32.7398516 ,
#        21.20422766, 27.64451025, 21.35547313, 22.70799818, 31.40467247,
#        23.73032579, 20.38528076, 34.61328282, 37.00449349, 24.7577347 ,
#        21.49892901, 20.0626456 , 21.02569382,  6.69913368, 28.34058905,
#        21.45770978, 25.17182389, 36.20607695, 12.43165667, 18.70065036,
#        26.02442058, 30.99415683, 17.91570319, 27.63033413, 29.59791332,
#        33.06560272, 40.05061068, 19.10537077, 21.29978555, 32.62597036,
#        -5.15131462, 18.47969284, 16.15804289, 17.71536964, 18.59697836,
#        32.09495244,  1.71233266, 11.89231887, 21.91359906, 12.74863749,
#        26.76038077, 23.91151019, 19.530268  , 18.2510902 , 19.98849769,
#        22.54073387, 26.338592  , 19.97008073, 23.30605246, 27.15824207,
#        20.15385079, 35.68994191,  6.0129106 , 29.45266497, 17.7005409 ,
#        18.14473144, 21.67512245, 28.47993031, 19.3885684 ,  7.78305206,
#        23.96180272, 21.79158936, 28.82320052, 22.36685931, 23.50551684,
#        11.40106004,  9.21913   , 26.11826557, 28.6731272 ,  6.43477503,
#        35.6916946 ,  4.39944913, 30.99982584, 12.56317246, 22.81809649,
#        33.00711684, 21.97750512])

# %%
y_pred = model.predict(X_test)
df=pd.DataFrame({'y_test':Y_test,'y_pred':y_pred})
print(df)
# Out:
#      y_test     y_pred
# 195    50.0  36.879775
# 4      36.2  31.585738
# 434    11.7  20.345876
# 458    14.9  20.138405
# 39     30.8  29.388762
# ..      ...        ...
# 227    31.6  30.999826
# 405     5.0  12.563172
# 69     20.9  22.818096
# 231    31.7  33.007117
# 104    20.1  21.977505
#
# [102 rows x 2 columns]

# %%
mse = mean_squared_error(Y_test, y_pred)
rmse = np.sqrt(mse)
r2 = r2_score(Y_test, y_pred)

# %%
print("Mean Squared Error (MSE):", mse)
# Out:
# Mean Squared Error (MSE): 44.97075659879906
