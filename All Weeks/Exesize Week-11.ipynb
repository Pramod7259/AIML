# %%
pip install nltk
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import nltk

# Download the required resources
nltk.download("punkt")       # Standard Punkt tokenizer
nltk.download("punkt_tab")   # The new punkt_tab resource (needed for newer NLTK versions)
# Out:
# [nltk_data] Downloading package punkt to C:\Users\Pramoda A
# [nltk_data]     S\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.
# [nltk_data] Downloading package punkt_tab to C:\Users\Pramoda A
# [nltk_data]     S\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt_tab.zip.
# True

# %%
import nltk
nltk.download('all')
# Out:
# [nltk_data] Downloading collection 'all'
# [nltk_data]    |
# [nltk_data]    | Downloading package abc to C:\Users\Pramoda A
# [nltk_data]    |     S\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\abc.zip.
# [nltk_data]    | Downloading package alpino to C:\Users\Pramoda A
# [nltk_data]    |     S\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\alpino.zip.
# [nltk_data]    | Downloading package averaged_perceptron_tagger to
# [nltk_data]    |     C:\Users\Pramoda A S\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping taggers\averaged_perceptron_tagger.zip.
# [nltk_data]    | Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]    |     C:\Users\Pramoda A S\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping
# [nltk_data]    |       taggers\averaged_perceptron_tagger_eng.zip.
# [nltk_data]    | Downloading package averaged_perceptron_tagger_ru to
# ...

# %%
import warnings 
warnings.filterwarnings("ignore")

# %%
import nltk
from nltk.tokenize import sent_tokenize

# %%
df=open("C:/Users/Pramoda A S/Desktop/AIML Documents/nlpEx.txt")
text=df.read()
print(text)
# Out:
# ML model monitoring is the practice of tracking the performance of ML models in production to identify potential issues that can add negative business value. These practices help proactively monitor prediction quality issues, data relevance, model accuracy, and bias.
#
# ML monitoring constitutes the subset of AI observability where it showcases a bigger picture with testing, validation, explainability, and exploring unforeseen failure modes.
# The performance of ML models starts degrading over time. It can be due to data inconsistencies, skews, and drifts, making deployed models inaccurate and irrelevant. Appropriate ML monitoring helps identify precisely when the model performance started diminishing. Such proactive monitoring helps take required actions like retraining models or replacing models. It helps foster usersâ€™ trust in ML systems.

# %%
sen=sent_tokenize(text)

# %%
print("Number of sentence is :",len(sen))
for i in range(len(sen)):
    print("\nSentence",i+1,":\n",sen[i])
# Out:
# Number of sentence is : 8
#
# Sentence 1 :
#  ML model monitoring is the practice of tracking the performance of ML models in production to identify potential issues that can add negative business value.
#
# Sentence 2 :
#  These practices help proactively monitor prediction quality issues, data relevance, model accuracy, and bias.
#
# Sentence 3 :
#  ML monitoring constitutes the subset of AI observability where it showcases a bigger picture with testing, validation, explainability, and exploring unforeseen failure modes.
#
# Sentence 4 :
#  The performance of ML models starts degrading over time.
#
# Sentence 5 :
#  It can be due to data inconsistencies, skews, and drifts, making deployed models inaccurate and irrelevant.
#
# Sentence 6 :
#  Appropriate ML monitoring helps identify precisely when the model performance started diminishing.
#
# Sentence 7 :
#  Such proactive monitoring helps take required actions like retraining models or replacing models.
#
# Sentence 8 :
# ...

# %%
pip install wordcloud
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# !pip install scikit-image

# %%
# !pip install spacy

# %%
# !pip install spellchecker
