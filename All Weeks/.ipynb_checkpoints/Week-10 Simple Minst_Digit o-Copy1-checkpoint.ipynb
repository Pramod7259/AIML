# %% [markdown]
# # ------------------------Week-10 Minst_Digit------------------------------

# %%
# Import libraries
import tensorflow as tf
from tensorflow.keras import layers, models
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
# Load and preprocess data
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.mnist.load_data()
x_train, x_test = x_train / 255.0, x_test / 255.0

# %%
plt.matshow(x_train[12])
plt.show()

# %%
# Build model
model = models.Sequential([
    layers.Flatten(input_shape=(28, 28)),
    layers.Dense(128, activation='relu'),
    layers.Dropout(0.2),
    layers.Dense(10, activation='softmax')
])

# %%
# Compile & train
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
model.fit(x_train, y_train, epochs=5, validation_data=(x_test, y_test))
# Out:
# Epoch 1/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.9122 - loss: 0.3017 - val_accuracy: 0.9586 - val_loss: 0.1387
# Epoch 2/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9567 - loss: 0.1432 - val_accuracy: 0.9671 - val_loss: 0.1127
# Epoch 3/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9674 - loss: 0.1087 - val_accuracy: 0.9727 - val_loss: 0.0885
# Epoch 4/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9722 - loss: 0.0880 - val_accuracy: 0.9762 - val_loss: 0.0791
# Epoch 5/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9771 - loss: 0.0737 - val_accuracy: 0.9780 - val_loss: 0.0735

# %%
plt.matshow(x_test[0])

# %%
# Evaluate model
test_loss, test_acc = model.evaluate(x_test, y_test)
print(f"\nTest Accuracy: {test_acc:.4f}")
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9780 - loss: 0.0735
#
# Test Accuracy: 0.9780

# %%
# Predict and create confusion matrix
y_pred = model.predict(x_test)
y_pred_classes = y_pred.argmax(axis=1)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step

# %%
cm = confusion_matrix(y_test, y_pred_classes)
cm
# Out:
# array([[ 973,    0,    0,    2,    0,    0,    1,    0,    4,    0],
#        [   0, 1127,    2,    2,    0,    0,    2,    1,    1,    0],
#        [   7,    1, 1005,    4,    4,    0,    2,    5,    4,    0],
#        [   0,    0,    7,  991,    0,    1,    0,    6,    3,    2],
#        [   2,    0,    2,    0,  969,    0,    3,    1,    2,    3],
#        [   2,    0,    0,   22,    1,  856,    4,    1,    5,    1],
#        [  10,    3,    0,    1,    4,    2,  937,    0,    1,    0],
#        [   1,    3,    8,    1,    1,    0,    0, 1010,    1,    3],
#        [   4,    0,    3,    5,    3,    0,    1,    5,  950,    3],
#        [   3,    5,    0,    8,   16,    4,    0,    8,    3,  962]])

# %%
# Plot heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.title("Confusion Matrix Heatmap - MNIST Digit Classification\n")
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.show()
