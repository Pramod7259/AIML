# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
df=pd.read_csv("C:/Users/Pramoda A S/Desktop/AIML Documents/DataSets in CSV files/phone_data_proje.csv")
df
# Out:
#             phone_name   brand           os  battery(MH)  ram(GB)  \
# 0         Y6II Compact  Huawei  Android 5.1         2200        2
# 1             K20 plus      LG  Android 7.0         2700        2
# 2       P8 Lite (2017)  Huawei  Android 7.0         3000        4
# 3         Redmi Note 4  Xiaomi  Android 6.0         4100        4
# 4                  P10  Huawei  Android 7.0         3200        4
# ...                ...     ...          ...          ...      ...
# 1506         vivo Y77t    Vivo   Android 13         5000        8
# 1507               11x  Realme   Android 13         5000        8
# 1508               GT5  Realme   Android 13         5240       16
# 1509          GT5 240W  Realme   Android 13         4600       24
# 1510  vivo iQOO Z7 Pro    Vivo   Android 13         4600        8
#
#       storage(GB)  price(USD $)
# 0            16.0       120.000
# 1            16.0       100.000
# 2            16.0       420.000
# 3            32.0       150.000
# 4            32.0       420.000
# ...           ...           ...
# 1506        256.0       170.000
# 1507        128.0       182.880
# 1508        256.0       380.000
# 1509          1.0       470.000
# 1510        128.0       287.988
#
# [1511 rows x 7 columns]

# %% [markdown]
# # Convert the string to float

# %%
df=pd.get_dummies(df,drop_first=True)

# %% [markdown]
# # Show the statistical info

# %%
df.describe()
# Out:
#        battery(MH)      ram(GB)  storage(GB)  price(USD $)
# count  1511.000000  1511.000000  1510.000000   1511.000000
# mean   4390.718729     6.686300   109.277483    337.752957
# std     784.050926     2.700663    74.420584    266.804037
# min    1821.000000     1.000000     1.000000     40.000000
# 25%    4000.000000     4.000000    64.000000    179.995000
# 50%    4500.000000     8.000000   128.000000    260.000000
# 75%    5000.000000     8.000000   128.000000    400.000000
# max    7250.000000    24.000000   512.000000   2300.000000

# %% [markdown]
# # Show the size of DataFrame

# %%
df.shape
# Out:
# (1511, 1543)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1511 entries, 0 to 1510
# Columns: 1543 entries, battery(MH) to os_iOS 16
# dtypes: bool(1539), float64(2), int64(2)
# memory usage: 2.3 MB

# %% [markdown]
# # Preprocesssing

# %% [markdown]
# ## Are there any null or missing values?

# %%
df.isnull().sum()
# Out:
# battery(MH)      0
# ram(GB)          0
# storage(GB)      1
# price(USD $)     0
# phone_name_10    0
#                 ..
# os_iOS 13        0
# os_iOS 14.1      0
# os_iOS 15        0
# os_iOS 15.4      0
# os_iOS 16        0
# Length: 1543, dtype: int64

# %% [markdown]
# ## Fill the missing values using mean.

# %%
a=df['storage(GB)'].mean()
a
# Out:
# np.float64(109.2774834437086)

# %%
df['storage(GB)']=df['storage(GB)'].fillna(a)

# %%
df.isnull().sum()
# Out:
# battery(MH)      0
# ram(GB)          0
# storage(GB)      0
# price(USD $)     0
# phone_name_10    0
#                 ..
# os_iOS 13        0
# os_iOS 14.1      0
# os_iOS 15        0
# os_iOS 15.4      0
# os_iOS 16        0
# Length: 1543, dtype: int64

# %% [markdown]
# ## Are there any duplicates?

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ## Checking the outliers

# %%
df['battery(MH)'].plot(kind='box')
plt.show()

# %% [markdown]
# ## Replace the outliers using IQR method

# %%
q1=df['battery(MH)'].quantile(0.25)
q3=df['battery(MH)'].quantile(0.75)
iqr=q3-q1

# %%
upper_bound=q3+(1.5*iqr)
lower_bound=q1-(1.5*iqr)

# %%
bat_arr=df['battery(MH)']
out=bat_arr[(bat_arr<=lower_bound)|(bat_arr>=upper_bound)]                                    
print(out)
# Out:
# 0       2200
# 5       2300
# 19      2500
# 27      2200
# 28      2050
# 45      1950
# 61      1821
# 68      2000
# 77      7000
# 89      2410
# 98      2500
# 115     2500
# 132     2280
# 186     2500
# 244     2500
# 535     1821
# 572     7250
# 641     7000
# 700     2227
# 763     7000
# 768     7000
# 947     2438
# 1084    6550
# 1094    2018
# 1447    7000
# 1491    6550
# Name: battery(MH), dtype: int64

# %%
batt_arr=df['battery(MH)']
lower_cap=np.percentile(batt_arr,1)
upper_cap=np.percentile(batt_arr,99)

# %%
for i in df['battery(MH)']:
    if i <lower_bound:
        df['battery(MH)']=df['battery(MH)'].replace(i,lower_cap)
    elif i >upper_bound:
        df['battery(MH)']=df['battery(MH)'].replace(i,upper_cap)

# %%
df['battery(MH)'].plot(kind='box')
# Out:
# <Axes: >

# %%
df['ram(GB)'].plot(kind='box')
plt.show()

# %%
q1=df['ram(GB)'].quantile(0.25)
q3=df['ram(GB)'].quantile(0.75)
iqr=q3-q1

upper_bound=q3+(1.5*iqr)
lower_bound=q1-(1.5*iqr) 

bat_arr=df['ram(GB)']
out=bat_arr[(bat_arr<=lower_bound)|(bat_arr>=upper_bound)]                                    

batt_arr=df['ram(GB)']
lower_cap=np.percentile(batt_arr,1)
upper_cap=np.percentile(batt_arr,99) 

for i in df['ram(GB)']:
    if i <lower_bound:
        df['ram(GB)']=df['ram(GB)'].replace(i,lower_cap)
    elif i >upper_bound:
        df['ram(GB)']=df['ram(GB)'].replace(i,upper_cap)

# %%
df['ram(GB)'].plot(kind='box')
plt.show()

# %%
df['storage(GB)'].plot(kind='box')
plt.show()

# %%
q1=df['storage(GB)'].quantile(0.25)
q3=df['storage(GB)'].quantile(0.75)
iqr=q3-q1

upper_bound=q3+(1.5*iqr)
lower_bound=q1-(1.5*iqr) 

bat_arr=df['storage(GB)']
out=bat_arr[(bat_arr<=lower_bound)|(bat_arr>=upper_bound)]                                    

batt_arr=df['storage(GB)']
lower_cap=np.percentile(batt_arr,1)
upper_cap=np.percentile(batt_arr,99) 

for i in df['storage(GB)']:
    if i <lower_bound:
        df['storage(GB)']=df['storage(GB)'].replace(i,lower_cap)
    elif i >upper_bound:
        df['storage(GB)']=df['storage(GB)'].replace(i,upper_cap)

# %%
df['storage(GB)'].plot(kind='box')
plt.show()

# %%
df.head()
# Out:
#    battery(MH)  ram(GB)  storage(GB)  price(USD $)  phone_name_10  \
# 0         2500        2         16.0         120.0          False
# 1         2700        2         16.0         100.0          False
# 2         3000        4         16.0         420.0          False
# 3         4100        4         32.0         150.0          False
# 4         3200        4         32.0         420.0          False
#
#    phone_name_10 5G  phone_name_10 Lite  phone_name_10 Pro  \
# 0             False               False              False
# 1             False               False              False
# 2             False               False              False
# 3             False               False              False
# 4             False               False              False
#
#    phone_name_10 Pro+  phone_name_10R  ...  os_EMUI 13  os_Tizen 3.0  \
# 0               False           False  ...       False         False
# 1               False           False  ...       False         False
# 2               False           False  ...       False         False
# 3               False           False  ...       False         False
# 4               False           False  ...       False         False
#
#    os_iOS 11  os_iOS 11.1.1  os_iOS 12  os_iOS 13  os_iOS 14.1  os_iOS 15  \
# 0      False          False      False      False        False      False
# 1      False          False      False      False        False      False
# 2      False          False      False      False        False      False
# 3      False          False      False      False        False      False
# 4      False          False      False      False        False      False
#
#    os_iOS 15.4  os_iOS 16
# 0        False      False
# 1        False      False
# 2        False      False
# 3        False      False
# 4        False      False
#
# [5 rows x 1543 columns]

# %%
df.head()
# Out:
#        phone_name   brand           os  battery(MH)  ram(GB)  storage(GB)  \
# 0    Y6II Compact  Huawei  Android 5.1         2500        2         16.0
# 1        K20 plus      LG  Android 7.0         2700        2         16.0
# 2  P8 Lite (2017)  Huawei  Android 7.0         3000        4         16.0
# 3    Redmi Note 4  Xiaomi  Android 6.0         4100        4         32.0
# 4             P10  Huawei  Android 7.0         3200        4         32.0
#
#    price(USD $)
# 0         120.0
# 1         100.0
# 2         420.0
# 3         150.0
# 4         420.0

# %% [markdown]
# # Multiple Linear Regression using Phone Price Prediction

# %% [markdown]
# ## Splitting the Data.

# %%
X = df.drop('price(USD $)',axis=1)
Y = df['price(USD $)']

# %% [markdown]
# ## Train the Linear Regression Model

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.2, random_state=200)
print(X_train.shape)
print(X_test.shape)
print(Y_train.shape)
print(Y_test.shape)
# Out:
# (1208, 1542)
# (303, 1542)
# (1208,)
# (303,)

# %% [markdown]
# ## Create a train Model

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score 


model = LinearRegression()
model.fit(X_train, Y_train)
# Out:
# LinearRegression()

# %% [markdown]
# ## Predict the Y_train Model

# %%
y_train_predict = model.predict(X_train)

# %% [markdown]
# ### Evaluation for Training set

# %%
rmse = (np.sqrt(mean_squared_error(Y_train, y_train_predict)))
r2 = r2_score(Y_train, y_train_predict)

print("The model performance for training set")
print("--------------------------------------")
print('RMSE is {}'.format(rmse))
print('R2 score is {}'.format(r2))
print("\n")
# Out:
# The model performance for training set
# --------------------------------------
# RMSE is 8.218927153184124e-11
# R2 score is 1.0

# %% [markdown]
# ## Predict the Y_test Model

# %%
y_test_predict = model.predict(X_test)

# %% [markdown]
# ### Evaluation for testing set

# %%
# root mean square error of the model
rmse = (np.sqrt(mean_squared_error(Y_test, y_test_predict)))

# r-squared score of the model
r2 = r2_score(Y_test, y_test_predict)

print("The model performance for testing set")
print("--------------------------------------")
print('RMSE is {}'.format(rmse))
print('R2 score is {}'.format(r2))
# Out:
# The model performance for testing set
# --------------------------------------
# RMSE is 260.1111058889002
# R2 score is 0.0012470934501670472
